# %%
import tensorflow as tf
import numpy as np

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import csv

# %%
vocab_size = 6000
embedding_dim =64
max_length = 200
trunc_type = 'pist'
padding_type = 'post'
oov_tok ='OOV'
training_portion =0.8
STOPWORDS = set(stopwords.words('english'))

# %%
articles = []
labels = []

with open("bbc-text.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        article = row[1]
        for word in STOPWORDS:
            token = ' ' + word + ' '
            article = article.replace(token, ' ')
            article = article.replace(' ', ' ')
        articles.append(article)
print(len(labels))
print(len(articles))
# Out:
# 2225
# 2225

# %%
train_size = int(len(articles) * training_portion)

train_articles = articles[0: train_size]
train_labels = labels[0: train_size]

validation_articles = articles[train_size:]
validation_labels = labels[train_size:]

print(train_size)
print(len(train_articles))
print(len(train_labels))
print(len(validation_articles))
print(len(validation_labels))
# Out:
# 1780
# 1780
# 1780
# 445
# 445

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
word_index

# %%
#Now replace values eith numbers
text_sequences = tokenizer.texts_to_sequences(train_articles)

# %%
print(text_sequences[:1])
print(train_articles[:1])

# %%
'''
Nlp requires the length of each seqience to be same, hence we use max length which is 200, 
sequence greater than 200 will be reduced to 200 and less yhan 200 will be padded as 0
'''

# %%
train_pad = pad_sequences(text_sequences,maxlen=max_length,padding= 'post',truncating = 'post')
train_pad
# Out:
# array([[  91,  160, 1141, ..., 5319,  294,  756],
#        [1857,  558,  222, ...,    0,    0,    0],
#        [4293,    1, 3655, ...,    0,    0,    0],
#        ...,
#        [   1, 2672, 2212, ...,  629,  171,    1],
#        [1931,   67,    1, ...,   81, 1977,    1],
#        [  91, 3813,    1, ...,    0,    0,    0]])

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length, padding='post', truncating='post')

print(len(validation_sequences))
print(validation_padded.shape)
# Out:
# 445
# (445, 200)

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %%
rev_word_ind = dict([(values,keys) for (keys , values) in word_index.items()])
rev_word_ind
# Out:
# {1: 'OOV',
#  2: 'said',
#  3: 'mr',
#  4: 'would',
#  5: 'year',
#  6: 'also',
#  7: 'people',
#  8: 'new',
#  9: 'us',
#  10: 'one',
#  11: 'could',
#  12: 'last',
#  13: 'first',
#  14: 'time',
#  15: 'two',
#  16: 'government',
#  17: 'world',
#  18: 'uk',
#  19: 'best',
#  20: 'years',
#  21: 'make',
#  22: 'film',
#  23: 'told',
#  24: 'made',
#  25: 'get',
#  26: 'music',
#  27: 'game',
#  28: 'like',
#  29: 'back',
#  30: 'many',
#  31: '000',
#  32: 'labour',
#  33: 'three',
#  34: 'well',
#  35: '1',
#  36: 'next',
#  37: 'bbc',
#  38: 'take',
#  39: 'set',
#  40: 'number',
#  41: 'added',
#  42: 'way',
#  43: 'market',
#  44: '2',
#  45: 'company',
#  46: 'may',
#  47: 'says',
#  48: 'election',
#  49: 'home',
#  50: 'party',
#  51: 'good',
#  52: 'going',
#  53: 'much',
#  54: 'work',
#  55: '2004',
#  56: 'still',
#  57: 'win',
#  58: 'show',
#  59: 'think',
#  60: 'games',
#  61: 'go',
#  62: 'top',
#  63: 'second',
#  64: 'million',
#  65: '6',
#  66: 'england',
#  67: 'firm',
#  68: 'since',
#  69: 'week',
#  70: 'say',
#  71: 'play',
#  72: 'part',
#  73: 'public',
#  74: 'use',
#  75: 'blair',
#  76: '3',
#  77: 'want',
#  78: 'minister',
#  79: 'however',
#  80: '10',
#  81: 'country',
#  82: 'technology',
#  83: 'see',
#  84: '4',
#  85: 'five',
#  86: 'british',
#  87: 'news',
#  88: 'european',
#  89: 'high',
#  90: 'group',
#  91: 'tv',
#  92: 'used',
#  93: 'end',
#  94: 'expected',
#  95: 'even',
#  96: 'players',
#  97: 'brown',
#  98: '5',
#  99: 'six',
#  100: 'old',
#  101: 'net',
#  102: 'already',
#  103: 'four',
#  104: 'plans',
#  105: 'put',
#  106: 'come',
#  107: 'half',
#  108: 'london',
#  109: 'sales',
#  110: 'growth',
#  111: 'long',
#  112: 'economy',
#  113: 'service',
#  114: 'right',
#  115: 'months',
#  116: 'chief',
#  117: 'day',
#  118: 'mobile',
#  119: 'former',
#  120: 'money',
#  121: 'britain',
#  122: 'director',
#  123: 'tax',
#  124: 'services',
#  125: '2005',
#  126: 'deal',
#  127: 'need',
#  128: 'help',
#  129: 'digital',
#  130: 'according',
#  131: 'big',
#  132: 'industry',
#  133: 'place',
#  134: 'companies',
#  135: 'users',
#  136: 'system',
#  137: 'business',
#  138: 'including',
#  139: 'team',
#  140: 'final',
#  141: 'based',
#  142: 'hit',
#  143: 'record',
#  144: 'report',
#  145: 'third',
#  146: 'called',
#  147: 'really',
#  148: 'international',
#  149: 'month',
#  150: 'move',
#  151: 'wales',
#  152: 'europe',
#  153: 'another',
#  154: '7',
#  155: 'life',
#  156: 'around',
#  157: 'economic',
#  158: 'start',
#  159: 'great',
#  160: 'future',
#  161: '2003',
#  162: 'firms',
#  163: 'came',
#  164: 'france',
#  165: 'open',
#  166: 'got',
#  167: 'spokesman',
#  168: 'software',
#  169: 'without',
#  170: 'general',
#  171: 'club',
#  172: 'up',
#  173: 'took',
#  174: 'ireland',
#  175: 'video',
#  176: 'howard',
#  177: 'know',
#  178: 'united',
#  179: 'online',
#  180: 'bank',
#  181: 'phone',
#  182: 'china',
#  183: 'far',
#  184: 'state',
#  185: 'campaign',
#  186: 'side',
#  187: 'law',
#  188: 'radio',
#  189: 'better',
#  190: 'court',
#  191: 'making',
#  192: 'decision',
#  193: 'executive',
#  194: 'real',
#  195: 'media',
#  196: 'offer',
#  197: 'give',
#  198: 'computer',
#  199: 'found',
#  200: 'action',
#  201: 'able',
#  202: 'president',
#  203: 'information',
#  204: 'despite',
#  205: 'office',
#  206: 'star',
#  207: 'lot',
#  208: 'national',
#  209: 'line',
#  210: 'countries',
#  211: 'likely',
#  212: 'using',
#  213: 'away',
#  214: 'player',
#  215: 'internet',
#  216: 'saying',
#  217: 'it',
#  218: 'every',
#  219: 'given',
#  220: 'security',
#  221: 'become',
#  222: 'left',
#  223: 'awards',
#  224: 'figures',
#  225: 'anti',
#  226: 'nations',
#  227: 'run',
#  228: 'eu',
#  229: '20',
#  230: 'cost',
#  231: 'prime',
#  232: 'role',
#  233: 'seen',
#  234: 'playing',
#  235: 'biggest',
#  236: 'man',
#  237: 'january',
#  238: 'data',
#  239: 'bill',
#  240: 'whether',
#  241: 'played',
#  242: 'later',
#  243: 'foreign',
#  244: 'although',
#  245: 'cup',
#  246: 'hard',
#  247: 'award',
#  248: 'rise',
#  249: 'broadband',
#  250: 'times',
#  251: 'match',
#  252: 'chancellor',
#  253: 'oil',
#  254: 'pay',
#  255: 'lost',
#  256: 'taking',
#  257: 'house',
#  258: 'due',
#  259: 'past',
#  260: 'interest',
#  261: 'early',
#  262: 'never',
#  263: 'lord',
#  264: 'leader',
#  265: 'support',
#  266: 'case',
#  267: 'prices',
#  268: 'look',
#  269: 'microsoft',
#  270: 'shares',
#  271: 'michael',
#  272: 'legal',
#  273: 'analysts',
#  274: 'control',
#  275: 'believe',
#  276: 'december',
#  277: 'less',
#  278: 'days',
#  279: 'cut',
#  280: 'recent',
#  281: 'season',
#  282: 'little',
#  283: 'children',
#  284: 'e',
#  285: 'ahead',
#  286: 'earlier',
#  287: 'increase',
#  288: 'thought',
#  289: 'free',
#  290: 'john',
#  291: 'face',
#  292: 'research',
#  293: 'scotland',
#  294: 'important',
#  295: 'something',
#  296: 'current',
#  297: 'strong',
#  298: 'went',
#  299: 'issue',
#  300: 'secretary',
#  301: 'south',
#  302: 'local',
#  303: 'tory',
#  304: 'rights',
#  305: 'working',
#  306: 'power',
#  307: 'budget',
#  308: 'financial',
#  309: 'spending',
#  310: '12',
#  311: 'quarter',
#  312: 'access',
#  313: 'currently',
#  314: 'held',
#  315: 'major',
#  316: 'chance',
#  317: 'change',
#  318: 'trade',
#  319: 'films',
#  320: 'find',
#  321: 'looking',
#  322: 'try',
#  323: 'following',
#  324: 'sunday',
#  325: '0',
#  326: 'full',
#  327: 'tories',
#  328: 'yet',
#  329: 'return',
#  330: 'series',
#  331: 'latest',
#  332: 'meeting',
#  333: 'share',
#  334: 'different',
#  335: 'website',
#  336: 'david',
#  337: 'winning',
#  338: 'almost',
#  339: 'injury',
#  340: 'sale',
#  341: 'must',
#  342: 'lead',
#  343: 'enough',
#  344: 'personal',
#  345: 'programme',
#  346: 'might',
#  347: 'police',
#  348: 'low',
#  349: 'band',
#  350: 'problems',
#  351: 'ever',
#  352: 'keep',
#  353: 'rate',
#  354: 'announced',
#  355: 'always',
#  356: 'key',
#  357: 'coach',
#  358: 'williams',
#  359: 'sold',
#  360: 'across',
#  361: 'performance',
#  362: 'dollar',
#  363: '11',
#  364: 'among',
#  365: 'behind',
#  366: 'ago',
#  367: 'list',
#  368: '8',
#  369: '9',
#  370: 'clear',
#  371: 'getting',
#  372: 'political',
#  373: 'victory',
#  374: '25',
#  375: 'mark',
#  376: 'chairman',
#  377: 'include',
#  378: 'women',
#  379: 'demand',
#  380: '30',
#  381: 'statement',
#  382: 'ms',
#  383: 'march',
#  384: 'february',
#  385: 'things',
#  386: 'term',
#  387: 'rather',
#  388: 'jobs',
#  389: 'minutes',
#  390: 'tuesday',
#  391: 'american',
#  392: 'chelsea',
#  393: 'claims',
#  394: 'done',
#  395: 'content',
#  396: 'continue',
#  397: 'point',
#  398: 'job',
#  399: 'manager',
#  400: 'means',
#  401: 'head',
#  402: 'problem',
#  403: 'title',
#  404: 'actor',
#  405: 'coming',
#  406: 'huge',
#  407: 'price',
#  408: 'asked',
#  409: 'released',
#  410: 'taken',
#  411: 'mail',
#  412: 'men',
#  413: 'union',
#  414: 'members',
#  415: 'india',
#  416: 'allow',
#  417: 'weeks',
#  418: 'wednesday',
#  419: 'act',
#  420: 'japan',
#  421: 'rugby',
#  422: 'plan',
#  423: 'tony',
#  424: 'global',
#  425: 'investment',
#  426: 'least',
#  427: 'result',
#  428: 'apple',
#  429: '50',
#  430: 'young',
#  431: 'network',
#  432: 'today',
#  433: 'within',
#  434: 'costs',
#  435: 'fans',
#  436: 'forward',
#  437: 'bid',
#  438: 'main',
#  439: 'french',
#  440: 'possible',
#  441: 'production',
#  442: 'needed',
#  443: 'running',
#  444: 'site',
#  445: 'beat',
#  446: 'november',
#  447: '18',
#  448: 'small',
#  449: 'war',
#  450: 'council',
#  451: 'consumer',
#  452: 'available',
#  453: 'saturday',
#  454: 'form',
#  455: 'warned',
#  456: 'thing',
#  457: 'monday',
#  458: 'cash',
#  459: 'vote',
#  460: 'hold',
#  461: 'several',
#  462: 'known',
#  463: 'wanted',
#  464: 'mps',
#  465: 'song',
#  466: 'pc',
#  467: 'issues',
#  468: 'total',
#  469: 'committee',
#  470: 'friday',
#  471: '15',
#  472: 'level',
#  473: 'live',
#  474: 'football',
#  475: 'though',
#  476: 'evidence',
#  477: 'policy',
#  478: 'prize',
#  479: 'version',
#  480: 'success',
#  481: 'led',
#  482: 'league',
#  483: 'search',
#  484: 'trying',
#  485: '2001',
#  486: 'human',
#  487: 'calls',
#  488: 'previous',
#  489: 'buy',
#  490: 'sir',
#  491: 'recently',
#  492: 'saw',
#  493: 'web',
#  494: 'sony',
#  495: 'rates',
#  496: 'family',
#  497: 'parties',
#  498: 'aid',
#  499: 'single',
#  500: 'album',
#  501: 'centre',
#  502: 'eight',
#  503: 'name',
#  504: 'customers',
#  505: 'rules',
#  506: 'meet',
#  507: 'close',
#  508: 'development',
#  509: 'ministers',
#  510: 'others',
#  511: 'thursday',
#  512: 'health',
#  513: 'book',
#  514: 'competition',
#  515: 'stock',
#  516: 'agreed',
#  517: 'call',
#  518: 'phones',
#  519: '100',
#  520: 'difficult',
#  521: 'short',
#  522: 'let',
#  523: 'race',
#  524: 'yukos',
#  525: 'consumers',
#  526: 'popular',
#  527: 'comes',
#  528: 'co',
#  529: 'fact',
#  530: 'charles',
#  531: 'event',
#  532: 'hope',
#  533: 'failed',
#  534: 'fourth',
#  535: 'higher',
#  536: 'showed',
#  537: 'networks',
#  538: 'debt',
#  539: 'board',
#  540: 'actress',
#  541: 'commission',
#  542: 'trial',
#  543: 'city',
#  544: 'wants',
#  545: 'october',
#  546: 'italy',
#  547: 'choice',
#  548: 'york',
#  549: 'lib',
#  550: 'reported',
#  551: 'feel',
#  552: 'nothing',
#  553: 'conference',
#  554: 'project',
#  555: 'career',
#  556: 'bt',
#  557: 'sites',
#  558: 'boss',
#  559: 'to',
#  560: 'points',
#  561: 'liberal',
#  562: 'late',
#  563: 'sure',
#  564: 'liverpool',
#  565: 'festival',
#  566: 'reports',
#  567: 'black',
#  568: 'received',
#  569: 'cannot',
#  570: 'annual',
#  571: 'together',
#  572: 'instead',
#  573: 'claim',
#  574: 'shows',
#  575: 'gaming',
#  576: 'tour',
#  577: 'dvd',
#  578: 'break',
#  579: 'launch',
#  580: 'claimed',
#  581: 'paid',
#  582: 'mean',
#  583: 'on',
#  584: 'devices',
#  585: 'christmas',
#  586: 'jones',
#  587: 'movie',
#  588: 'boost',
#  589: 'goal',
#  590: 'virus',
#  591: 'growing',
#  592: 'stage',
#  593: 'release',
#  594: 'age',
#  595: 'largest',
#  596: 'september',
#  597: 'large',
#  598: 'leading',
#  599: 'summer',
#  600: 'champion',
#  601: '2002',
#  602: 'involved',
#  603: 'position',
#  604: 'arsenal',
#  605: 'west',
#  606: 'denied',
#  607: 'changes',
#  608: 'russian',
#  609: 'in',
#  610: 'out',
#  611: 'believes',
#  612: 'manchester',
#  613: 'profits',
#  614: 'paul',
#  615: 'singer',
#  616: 'iraq',
#  617: 'needs',
#  618: 'fall',
#  619: 'television',
#  620: 'products',
#  621: 'idea',
#  622: 'stop',
#  623: 'them',
#  624: 'gordon',
#  625: 'parliament',
#  626: '17',
#  627: 'australian',
#  628: 'pressure',
#  629: 'sport',
#  630: 'love',
#  631: 'germany',
#  632: 'africa',
#  633: 'started',
#  634: 'create',
#  635: 'order',
#  636: 'scottish',
#  637: 'talks',
#  638: 'giant',
#  639: 'potential',
#  640: '13',
#  641: 'german',
#  642: 'test',
#  643: 'pre',
#  644: 'weekend',
#  645: '16',
#  646: 'quite',
#  647: 'round',
#  648: 'opening',
#  649: 'whole',
#  650: 'that',
#  651: 'squad',
#  652: 'martin',
#  653: 'association',
#  654: 'special',
#  655: 'senior',
#  656: 'launched',
#  657: 'box',
#  658: 'chart',
#  659: 'oscar',
#  660: 'seven',
#  661: 'street',
#  662: 'rose',
#  663: 'value',
#  664: 'conservative',
#  665: 'sent',
#  666: 'stars',
#  667: 'ball',
#  668: 'car',
#  669: 'v',
#  670: 'anything',
#  671: 'grand',
#  672: 'groups',
#  673: 'hours',
#  674: 'accused',
#  675: '40',
#  676: 'stand',
#  677: 'remain',
#  678: '2000',
#  679: 'cards',
#  680: 'either',
#  681: 'hopes',
#  682: 'ensure',
#  683: 'olympic',
#  684: 'simply',
#  685: 'robinson',
#  686: 'fight',
#  687: 'similar',
#  688: 'press',
#  689: 'smith',
#  690: 'range',
#  691: 'irish',
#  692: 'drive',
#  693: '2006',
#  694: 'exchange',
#  695: 'rock',
#  696: 'official',
#  697: '24',
#  698: '14',
#  699: 'results',
#  700: 'bit',
#  701: 'appeal',
#  702: 'turn',
#  703: 'dr',
#  704: 'provide',
#  705: 'ukip',
#  706: 'immigration',
#  707: 'period',
#  708: 'makes',
#  709: 'target',
#  710: 'helped',
#  711: 'investors',
#  712: 'standard',
#  713: 'wrong',
#  714: 'sell',
#  715: 'attack',
#  716: 'commons',
#  717: 'fell',
#  718: 'independent',
#  719: 'tsunami',
#  720: 'particularly',
#  721: 'meanwhile',
#  722: 'comedy',
#  723: 'proposals',
#  724: 'education',
#  725: 'average',
#  726: 'energy',
#  727: 'lords',
#  728: 'ban',
#  729: 'gave',
#  730: 'impact',
#  731: 'via',
#  732: 'moment',
#  733: 'compared',
#  734: 'school',
#  735: 'happy',
#  736: 'card',
#  737: 'forced',
#  738: 'charge',
#  739: 'attacks',
#  740: 'spam',
#  741: 'generation',
#  742: 'force',
#  743: 'brought',
#  744: 'amount',
#  745: 'private',
#  746: 'community',
#  747: 'sector',
#  748: 'per',
#  749: 'bring',
#  750: 'fraud',
#  751: 'became',
#  752: 'fund',
#  753: 'euros',
#  754: 'extra',
#  755: 'systems',
#  756: 'everyone',
#  757: 'speech',
#  758: 'admitted',
#  759: 'poll',
#  760: 'history',
#  761: 'message',
#  762: 'numbers',
#  763: 'included',
#  764: 'widely',
#  765: 'gadget',
#  766: 'entertainment',
#  767: 'windows',
#  768: 'debate',
#  769: 'speaking',
#  770: 'selling',
#  771: 'hand',
#  772: 'bad',
#  773: 'department',
#  774: 'laws',
#  775: 'workers',
#  776: 'date',
#  777: 'australia',
#  778: 'charges',
#  779: 'markets',
#  780: 'night',
#  781: 'audience',
#  782: 'named',
#  783: 're',
#  784: 'russia',
#  785: 'comments',
#  786: 'soon',
#  787: 'worked',
#  788: 'staff',
#  789: 'agency',
#  790: 'off',
#  791: 'view',
#  792: 'turned',
#  793: 'kilroy',
#  794: 'mike',
#  795: 'front',
#  796: 'member',
#  797: 'shot',
#  798: 'bush',
#  799: 'revealed',
#  800: 'areas',
#  801: 'download',
#  802: 'takes',
#  803: 'speed',
#  804: 'screen',
#  805: 'increased',
#  806: 'all',
#  807: 'opposition',
#  808: 'university',
#  809: 'battle',
#  810: 'civil',
#  811: 'kennedy',
#  812: 'spend',
#  813: 'air',
#  814: 'finance',
#  815: 'newspaper',
#  816: 'him',
#  817: 'opportunity',
#  818: 'concerns',
#  819: 'shown',
#  820: 'survey',
#  821: 'area',
#  822: 'cross',
#  823: 'white',
#  824: 'gone',
#  825: 'voters',
#  826: 'course',
#  827: 'original',
#  828: 'millions',
#  829: 'bought',
#  830: 'offered',
#  831: 'â£1',
#  832: 'poor',
#  833: 'alan',
#  834: 'followed',
#  835: 'east',
#  836: 'concerned',
#  837: 'leave',
#  838: 'often',
#  839: 'decided',
#  840: 'insisted',
#  841: 'authorities',
#  842: 'outside',
#  843: 'b',
#  844: 'favourite',
#  845: 'terms',
#  846: 'defence',
#  847: 'step',
#  848: 'whose',
#  849: 'june',
#  850: 'story',
#  851: 'reached',
#  852: 'analyst',
#  853: 'lives',
#  854: 'created',
#  855: 'designed',
#  856: 'mini',
#  857: 'process',
#  858: 'non',
#  859: 'risk',
#  860: '22',
#  861: 'america',
#  862: 'body',
#  863: 'quality',
#  864: 'easy',
#  865: 'spent',
#  866: 'cuts',
#  867: 'becoming',
#  868: 'remains',
#  869: 'unit',
#  870: 'majority',
#  871: 'raise',
#  872: 'pop',
#  873: 'attempt',
#  874: 'musical',
#  875: 'r',
#  876: 'drugs',
#  877: 'hollywood',
#  878: 'challenge',
#  879: 'experience',
#  880: 'example',
#  881: '19',
#  882: 'debut',
#  883: 'nominated',
#  884: 'states',
#  885: 'reach',
#  886: 'credit',
#  887: 'messages',
#  888: 'levels',
#  889: 'winner',
#  890: 'ray',
#  891: 'robert',
#  892: 'silk',
#  893: 'watch',
#  894: 'andy',
#  895: 'situation',
#  896: 'focus',
#  897: 'taxes',
#  898: 'euro',
#  899: 'songs',
#  900: 'organisation',
#  901: 'build',
#  902: 'everything',
#  903: 'believed',
#  904: 'april',
#  905: 'tough',
#  906: 'central',
#  907: 'anyone',
#  908: 'signed',
#  909: 'j',
#  910: 'pcs',
#  911: 'captain',
#  912: 'rival',
#  913: 'device',
#  914: 'indian',
#  915: 'confirmed',
#  916: 'james',
#  917: 'so',
#  918: 'titles',
#  919: 'businesses',
#  920: 'post',
#  921: 'technologies',
#  922: 'critics',
#  923: 'matter',
#  924: 'previously',
#  925: 'trading',
#  926: 'rest',
#  927: 'met',
#  928: 'began',
#  929: 'longer',
#  930: 'officials',
#  931: 'response',
#  932: 'probably',
#  933: 'nine',
#  934: 'hour',
#  935: 'row',
#  936: 'minute',
#  937: 'light',
#  938: 'cases',
#  939: 'magazine',
#  940: 'building',
#  941: 'worth',
#  942: 'account',
#  943: 'voice',
#  944: 'programs',
#  945: 'ask',
#  946: 'looked',
#  947: 'mp',
#  948: 'davis',
#  949: 'aviator',
#  950: 'threat',
#  951: 'trust',
#  952: 'confidence',
#  953: 'looks',
#  954: 'g',
#  955: 'chinese',
#  956: 'machine',
#  957: 'gold',
#  958: 'category',
#  959: 'computers',
#  960: 'premiership',
#  961: 'host',
#  962: 'measures',
#  963: 'fast',
#  964: 'person',
#  965: 'ruled',
#  966: 'towards',
#  967: 'artists',
#  968: 'double',
#  969: 'training',
#  970: 'missed',
#  971: 'felt',
#  972: 'care',
#  973: 'agreement',
#  974: 'allowed',
#  975: 'madrid',
#  976: 'scheme',
#  977: 'zealand',
#  978: 'fear',
#  979: 'theatre',
#  980: 'portable',
#  981: 'newcastle',
#  982: 'north',
#  983: 'serious',
#  984: 'spain',
#  985: 'management',
#  986: 'banks',
#  987: 'program',
#  988: 'figure',
#  989: 'johnson',
#  990: 'positive',
#  991: 'affected',
#  992: 'champions',
#  993: 'file',
#  994: 'deutsche',
#  995: 'google',
#  996: 'kept',
#  997: 'rising',
#  998: 'rule',
#  999: 'argued',
#  1000: 'along',
#  ...}

# %%
def decode_articles(text):
    return ' '.join([rev_word_ind.get(i,'???')for i in text])
decode_articles(train_pad[1])
# Out:
# 'worldcom boss left books alone former worldcom boss OOV ebbers accused OOV 11bn â£5 8bn fraud never made accounting decisions witness told jurors david OOV made comments questioning defence lawyers arguing mr ebbers responsible worldcom problems phone company collapsed 2002 prosecutors claim losses hidden protect firm shares mr OOV already pleaded guilty fraud OOV prosecutors monday defence lawyer reid OOV tried distance client allegations cross OOV asked mr OOV ever knew mr ebbers make accounting decision aware mr OOV replied ever know mr ebbers make accounting entry worldcom books mr OOV OOV replied witness mr OOV admitted ordered false accounting entries request former worldcom chief financial officer scott sullivan defence lawyers trying OOV mr sullivan admitted fraud OOV later trial OOV behind worldcom accounting house cards mr ebbers team meanwhile looking OOV OOV boss admission OOV OOV economist whatever OOV mr ebbers OOV worldcom OOV unknown OOV telecoms giant investor OOV late 1990s worldcom problems OOV however competition increased telecoms boom OOV out firm finally collapsed shareholders lost OOV 20 000 workers lost jobs mr ebbers trial expected last two months found guilty former OOV faces substantial jail sentence firmly declared OOV ??? ??? ??? ??? ??? ??? ??? ???'

# %%
#LSTMb`

# %%
model = tf.keras.Sequential([
    # Add an Embedding layer expecting input vocab of size 5000, and output embedding dimension of size 64 we set at the top
    tf.keras.layers.Embedding(vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
#    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    # use ReLU in place of tanh function since they are very good alternatives of each other.
    tf.keras.layers.Dense(embedding_dim, activation='relu'),
    # Add a Dense layer with 6 units and softmax activation.
    # When we have multiple outputs, softmax convert outputs layers into a probability distribution.
    tf.keras.layers.Dense(6, 'softmax')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 64)          384000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 458,694
# Trainable params: 458,694
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
num_epochs = 10
history = model.fit(train_pad, training_label_seq, epochs=num_epochs, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/10
# 56/56 - 8s - loss: 1.5705 - accuracy: 0.2596 - val_loss: 1.3396 - val_accuracy: 0.3865
# Epoch 2/10
# 56/56 - 6s - loss: 1.1419 - accuracy: 0.5360 - val_loss: 0.6676 - val_accuracy: 0.7506
# Epoch 3/10
# 56/56 - 7s - loss: 0.4081 - accuracy: 0.8612 - val_loss: 0.3661 - val_accuracy: 0.8989
# Epoch 4/10
# 56/56 - 6s - loss: 0.1186 - accuracy: 0.9702 - val_loss: 0.3043 - val_accuracy: 0.9169
# Epoch 5/10
# 56/56 - 7s - loss: 0.0480 - accuracy: 0.9865 - val_loss: 0.2502 - val_accuracy: 0.9213
# Epoch 6/10
# 56/56 - 7s - loss: 0.0239 - accuracy: 0.9944 - val_loss: 0.2666 - val_accuracy: 0.9281
# Epoch 7/10
# 56/56 - 6s - loss: 0.0281 - accuracy: 0.9910 - val_loss: 0.4531 - val_accuracy: 0.8652
# Epoch 8/10
# 56/56 - 7s - loss: 0.0267 - accuracy: 0.9927 - val_loss: 0.3216 - val_accuracy: 0.9236
# Epoch 9/10
# 56/56 - 6s - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.3237 - val_accuracy: 0.9146
# Epoch 10/10
# 56/56 - 7s - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.3580 - val_accuracy: 0.9281

# %%
txt = ["A WeWork shareholder has taken the company to court over the near-$1.7bn (£1.3bn) leaving package approved for ousted co-founder Adam Neumann."]
seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
np.argmax(pred)
# Out:
# 2

# %%
# Out:
# {'business', 'entertainment', 'politics', 'sport', 'tech'}
